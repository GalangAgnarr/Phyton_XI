# %%
print('hello world')
# Out:
# hello world

# %%
umur = 17
harga = 7.5
nama = "Muhamad Galang"
absen = [1, 2, 3]

print(f"umur: {umur} ({type(umur)})")
print(f"harga: {harga} ({type(harga)})")
print(f"nama: {nama} ({type(nama)})")
print(f"absen: {absen} ({type(absen)})")
# Out:
# umur: 17 (<class 'int'>)
# harga: 7.5 (<class 'float'>)
# nama: Muhamad Galang (<class 'str'>)
# absen: [1, 2, 3] (<class 'list'>)

# %%
belanja = ["beras", "minyak", "telur"]
belanja.append("gula")
belanja.append("kopi")

for item in belanja:
    print(item)
# Out:
# beras
# minyak
# telur
# gula
# kopi

# %%
harga_belanja = {
    "beras": 12000,
    "minyak": 17000,
    "telur": 24000,
    "gula": 15000,
    "kopi": 20000
}

total = 0
for barang, harga in harga_belanja.items():
    print(f"{barang}: {harga}")
    total += harga
print("Total belanja =", total)
# Out:
# beras: 12000
# minyak: 17000
# telur: 24000
# gula: 15000
# kopi: 20000
# Total belanja = 88000

# %%
def persegi_panjang(panjang, lebar):
    luas = panjang * lebar
    keliling = 2 * (panjang + lebar)
    return luas, keliling

luas, keliling = persegi_panjang(10, 5)
print("Luas =", luas)
print("Keliling =", keliling)
# Out:
# Luas = 50
# Keliling = 30

# %%
usia = int(input("Masukkan usia: "))
if 0 <= usia <= 13:
    print("Anak")
elif 14 <= usia <= 24:
    print("Remaja")
elif 25 <= usia <= 49:
    print("Dewasa")
elif usia >= 50:
    print("Lansia")
else:
    print("Usia tidak valid")
# Out:
# Dewasa
